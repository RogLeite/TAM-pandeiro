# %% [markdown]
# ##show()
# Se quiser ver o MusicXML, existe a dependência ao MuseScore, e precisa rodar o código abaixo localmente

# %%
"""
from os import remove, system, getcwd, listdir, mkdir
import music21 as m21
print("music21 version = ", m21.__version__)

#!rm MuseScore/*
#mkdir("MuseScore")
remove("MuseScore/*")

#!wget -P ./MuseScore https://cdn.jsdelivr.net/musescore/v3.4.2/MuseScore-3.4.2-x86_64.AppImage
system("wget -P ./MuseScore https://cdn.jsdelivr.net/musescore/v3.4.2/MuseScore-3.4.2-x86_64.AppImage")

#!pwd
print(getcwd())

#!ls -la
print(listdir(getcwd()))


us = m21.environment.Environment()
us["musicxmlPath"] = "MuseScore/MuseScore-3.4.2-x86_64.AppImage"
print(us["musicxmlPath"])
print("xmlReaderType = ", us.xmlReaderType())


m21.converter.parse("tinynotation: 3/4 c4 d8 f g16 a g f#").show()

#"""

# %% [markdown]
# ##write()
# Para escrever um arquivo MusicXML

# %%
#!pip3 install music21

# %%
import music21 as m21

s = m21.converter.parse("tinynotation: 3/4 c4 d8 f g16 a g f#")
s.write("musicxml", "som.musicxml")

from os import listdir
listdir()
# Out:
# ['.config', 'som.musicxml', 'sample_data']
